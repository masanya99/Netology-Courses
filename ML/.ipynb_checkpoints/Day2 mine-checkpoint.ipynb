# %%
import pandas as pd
# %matplotlib inline

import matplotlib
import numpy as np
import matplotlib.pyplot as plt

# %%
# 10 лет
# usd2= pd.read_excel('usd_.xlsx')
# usd2

# %%
# usd_rate.xlsx usd_.xlsx
# 3 года
dataframe= pd.read_excel('usd_rate.xlsx')
dataframe.head()
# Out:
#    nominal       data     curs         cdx
# 0        1 2017-08-01  60.0633  Доллар США
# 1        1 2017-08-02  59.8454  Доллар США
# 2        1 2017-08-03  60.5819  Доллар США
# 3        1 2017-08-04  60.7503  Доллар США
# 4        1 2017-08-05  60.3281  Доллар США

# %%
rate = dataframe.curs
rate
# Out:
# 0      60.0633
# 1      59.8454
# 2      60.5819
# 3      60.7503
# 4      60.3281
#         ...
# 733    71.5850
# 734    71.9196
# 735    72.2348
# 736    73.3633
# 737    73.4261
# Name: curs, Length: 738, dtype: float64

# %%
plt.plot(rate, color = 'r')
plt.show()

# %%
past = 28 
# 4 недели для прогноза из прошлого

# %%
length = len(rate)
count = length - past
print(f'с {past} по {length} день\nвсего - {count} дней')
# Out:
# с 28 по 738 день
# всего - 710 дней

# %%
past_days= []
current_days= []
for day in range(past, length):
    past_days.append(list(rate[(day-past):day])) #0:29
    current_days.append(rate[day])   #29 rate[day:day+3]

# %%
past_columns = []
for i in range(past):
    past_columns.append(f'past_{i}')

# %%
X = pd.DataFrame(data = past_days, columns=past_columns)

# %%
y = pd.Series(current_days, name = 'target')

# %%
# train
X_train = X[:-10]
y_train = y[:-10]

# %%
# test
X_test = X[-10:]
y_test = y[-10:]

# %%
from sklearn.metrics import mean_absolute_error

# %%
scores= pd.DataFrame()
def predictions_plots(model,model_name):
    
    model.fit(X_train, y_train)
    prediction = model.predict(X_test)
    
    number = len(scores)
    scores.loc[number,'model'] = model_name
    scores.loc[number,'score'] = mean_absolute_error(prediction,y_test)
    print(scores)
    
    plt.plot(prediction, label = 'Predicton '+model_name, color='r')
    plt.plot(list(y_test),label = 'Real', color='g')
    plt.legend()
    plt.show()

# -----------------
    try:
        imp = pd.Series(list(model.coef_), name='importances') 
    except AttributeError:
        imp = pd.Series(list(model.feature_importances_), name='importances') 
    cols = pd.Series(past_columns, name='columns')
    df = pd.DataFrame(cols)
    df['imp'] = imp
    print(df)

# %%
from sklearn.linear_model import LinearRegression

# %%
predictions_plots(LinearRegression(),'LinearRegression')
# Out:
#               model     score
# 0  LinearRegression  0.415963
#     columns       imp
# 0    past_0  0.039324
# 1    past_1 -0.086728
# 2    past_2  0.049472
# 3    past_3 -0.010744
# 4    past_4  0.046257
# 5    past_5 -0.123448
# 6    past_6  0.152137
# 7    past_7 -0.085485
# 8    past_8  0.029402
# 9    past_9 -0.037413
# 10  past_10  0.069960
# 11  past_11 -0.119729
# 12  past_12  0.027159
# 13  past_13  0.081719
# 14  past_14 -0.054678
# 15  past_15 -0.003655
# 16  past_16  0.125869
# 17  past_17 -0.078727
# 18  past_18 -0.077024
# 19  past_19  0.103389
# 20  past_20 -0.073673
# 21  past_21  0.029959
# 22  past_22 -0.097939
# 23  past_23  0.085521
# 24  past_24 -0.012518
# 25  past_25 -0.015320
# 26  past_26  0.008524
# 27  past_27  1.019399

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
predictions_plots(RandomForestRegressor(),'RandomForestRegressor')
# Out:
#                    model     score
# 0       LinearRegression  0.415963
# 1  RandomForestRegressor  0.595869
#     columns       imp
# 0    past_0  0.000762
# 1    past_1  0.000638
# 2    past_2  0.000552
# 3    past_3  0.000256
# 4    past_4  0.000614
# 5    past_5  0.001086
# 6    past_6  0.000508
# 7    past_7  0.000587
# 8    past_8  0.000499
# 9    past_9  0.000304
# 10  past_10  0.000410
# 11  past_11  0.000369
# 12  past_12  0.000596
# 13  past_13  0.000440
# 14  past_14  0.000688
# 15  past_15  0.000393
# 16  past_16  0.000369
# 17  past_17  0.000326
# 18  past_18  0.000358
# 19  past_19  0.000607
# 20  past_20  0.000536
# 21  past_21  0.000533
# 22  past_22  0.000429
# 23  past_23  0.000370
# 24  past_24  0.002692
# 25  past_25  0.006729
# 26  past_26  0.041106
# 27  past_27  0.937242

# %%
predictions_plots(LinearRegression(normalize=True),'LinearRegression_norm')
# Out:
#                    model     score
# 0       LinearRegression  0.415963
# 1  RandomForestRegressor  0.595869
# 2  LinearRegression_norm  0.415963
#     columns       imp
# 0    past_0  0.039324
# 1    past_1 -0.086728
# 2    past_2  0.049472
# 3    past_3 -0.010744
# 4    past_4  0.046257
# 5    past_5 -0.123448
# 6    past_6  0.152137
# 7    past_7 -0.085485
# 8    past_8  0.029402
# 9    past_9 -0.037413
# 10  past_10  0.069960
# 11  past_11 -0.119729
# 12  past_12  0.027159
# 13  past_13  0.081719
# 14  past_14 -0.054678
# 15  past_15 -0.003655
# 16  past_16  0.125869
# 17  past_17 -0.078727
# 18  past_18 -0.077024
# 19  past_19  0.103389
# 20  past_20 -0.073673
# 21  past_21  0.029959
# 22  past_22 -0.097939
# 23  past_23  0.085521
# 24  past_24 -0.012518
# 25  past_25 -0.015320
# 26  past_26  0.008524
# 27  past_27  1.019399

# %%
from sklearn.neural_network import MLPRegressor

# %%
predictions_plots(MLPRegressor(),'MLPRegressor')
# Out:
#                    model     score
# 0       LinearRegression  0.415963
# 1  RandomForestRegressor  0.595869
# 2  LinearRegression_norm  0.415963
# 3           MLPRegressor  0.994816
# /Users/annamaslova/opt/anaconda3/lib/python3.7/site-packages/sklearn/neural_network/_multilayer_perceptron.py:571: ConvergenceWarning: Stochastic Optimizer: Maximum iterations (200) reached and the optimization hasn't converged yet.
#   % self.max_iter, ConvergenceWarning)
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-162-103589c45ea5> in predictions_plots(model, model_name)
#      18     try:
# ---> 19         imp = pd.Series(list(model.coef_), name='importances')
#      20     except AttributeError:
#
# AttributeError: 'MLPRegressor' object has no attribute 'coef_'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-170-2b4a349075c9> in <module>
# ----> 1 predictions_plots(MLPRegressor(),'MLPRegressor')
#
# <ipython-input-162-103589c45ea5> in predictions_plots(model, model_name)
#      19         imp = pd.Series(list(model.coef_), name='importances')
#      20     except AttributeError:
# ---> 21         imp = pd.Series(list(model.feature_importances_), name='importances')
#      22     cols = pd.Series(past_columns, name='columns')
#      23     df = pd.DataFrame(cols)
#
# AttributeError: 'MLPRegressor' object has no attribute 'feature_importances_'

# %%
from sklearn.neighbors import KNeighborsRegressor

# %%
predictions_plots(KNeighborsRegressor(n_neighbors=3),'KNeighborsRegressor_3')
# Out:
#                    model     score
# 0       LinearRegression  0.415963
# 1  RandomForestRegressor  0.595869
# 2  LinearRegression_norm  0.415963
# 3           MLPRegressor  0.994816
# 4  KNeighborsRegressor_3  0.837817
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-162-103589c45ea5> in predictions_plots(model, model_name)
#      18     try:
# ---> 19         imp = pd.Series(list(model.coef_), name='importances')
#      20     except AttributeError:
#
# AttributeError: 'KNeighborsRegressor' object has no attribute 'coef_'
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# <ipython-input-172-e92d1b3faa29> in <module>
# ----> 1 predictions_plots(KNeighborsRegressor(n_neighbors=3),'KNeighborsRegressor_3')
#
# <ipython-input-162-103589c45ea5> in predictions_plots(model, model_name)
#      19         imp = pd.Series(list(model.coef_), name='importances')
#      20     except AttributeError:
# ---> 21         imp = pd.Series(list(model.feature_importances_), name='importances')
#      22     cols = pd.Series(past_columns, name='columns')
#      23     df = pd.DataFrame(cols)
#
# AttributeError: 'KNeighborsRegressor' object has no attribute 'feature_importances_'

# %%
from sklearn.ensemble import GradientBoostingRegressor

# %%
predictions_plots(GradientBoostingRegressor(n_estimators=1000, max_depth=10),
                  'GradientBoostingRegressor')
# Out:
#                        model     score
# 0           LinearRegression  0.415963
# 1      RandomForestRegressor  0.595869
# 2      LinearRegression_norm  0.415963
# 3               MLPRegressor  0.994816
# 4      KNeighborsRegressor_3  0.837817
# 5  GradientBoostingRegressor  0.690373
#     columns       imp
# 0    past_0  0.000622
# 1    past_1  0.000539
# 2    past_2  0.000113
# 3    past_3  0.000299
# 4    past_4  0.000865
# 5    past_5  0.000875
# 6    past_6  0.000390
# 7    past_7  0.001305
# 8    past_8  0.001241
# 9    past_9  0.000177
# 10  past_10  0.000391
# 11  past_11  0.000288
# 12  past_12  0.000829
# 13  past_13  0.000249
# 14  past_14  0.000540
# 15  past_15  0.000190
# 16  past_16  0.000459
# 17  past_17  0.000313
# 18  past_18  0.000476
# 19  past_19  0.000591
# 20  past_20  0.000712
# 21  past_21  0.000523
# 22  past_22  0.000502
# 23  past_23  0.000299
# 24  past_24  0.000319
# 25  past_25  0.001243
# 26  past_26  0.000881
# 27  past_27  0.984769
